# %% [markdown]
# <a href="https://colab.research.google.com/github/sharadyadav-ai/python-projets/blob/main/Object_Detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
""
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ''

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.predict(source=r"/images2.jpg")
# Out:
# image 1/1 /images2.jpg: 416x640 2 persons, 1 car, 1 bus, 1 truck, 183.5ms
# Speed: 6.7ms preprocess, 183.5ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=289x175>
